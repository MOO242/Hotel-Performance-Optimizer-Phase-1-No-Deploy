# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.components.data_ingestion import engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 from src.components.data_ingestion import engine
#
# ModuleNotFoundError: No module named 'src'

# %%
from sqlalchemy import engine

fact_bookings_df = pd.read_sql('fact_bookings',engine)
print(fact_bookings_df.info())
# Out:
# C:\Windows\Temp\ipykernel_15456\2158205987.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   fact_bookings_df = pd.read_sql('fact_bookings',engine)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from sqlalchemy import engine
# ----> 3 fact_bookings_df = pd.read_sql('fact_bookings',engine)
#       4 print(fact_bookings_df.info())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
# ...
